# %% [markdown]
# # Ripgrep Contextual Search Example
# This notebook demonstrates how to use ripgrep to search for patterns in files, including lines before and after each match, and store the results in a pandas DataFrame for contextual analysis.

# %%
# Import required libraries
import subprocess
import pandas as pd

# %% [markdown]
# ## Define ripgrep search function with context
# This function runs ripgrep with options to include lines before and after each match, and parses the output into a DataFrame.

# %%
def ripgrep_search_with_context(pattern, path='.', before=2, after=2, extra_args=None):
    cmd = ['rg', '--vimgrep', f'-B{before}', f'-A{after}', pattern, path]
    if extra_args:
        cmd.extend(extra_args)
    result = subprocess.run(cmd, capture_output=True, text=True)
    lines = result.stdout.strip().split('\n')
    data = []
    for line in lines:
        line_type = 'match'
        if line.startswith('--') or line.strip() == '':
            continue  # skip separator or empty lines
        if '-' in line and not line.startswith('-'):
            # context line, e.g. file-path-line-text
            parts = line.split('-', 2)
            if len(parts) == 3:
                file, line_num, text = parts
                data.append({'file': file, 'line': int(line_num), 'col': None, 'text': text, 'type': 'context'})
            continue
        if ':' in line:
            # match line, e.g. file-path:line:col:text
            parts = line.split(':', 3)
            if len(parts) == 4:
                file, line_num, col_num, text = parts
                try:
                    line_num = int(line_num)
                    col_num = int(col_num)
                except ValueError:
                    continue
                data.append({'file': file, 'line': line_num, 'col': col_num, 'text': text, 'type': 'match'})
            continue
    return pd.DataFrame(data)

# %% [markdown]
# ## Run a contextual search
# Search for the word 'def' in Python files, including 2 lines before and after each match, and display results.

# %%
df = ripgrep_search_with_context('def', path='C:/work/GitHub/dec-tree-py', before=2, after=2, extra_args=['--type', 'py'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Empty DataFrame

# %%
# Debug: Print raw ripgrep output to help diagnose parsing issues
cmd = ['rg', '--vimgrep', '-B2', '-A2', 'def', 'C:/work/GitHub/dec-tree-py', '--type', 'py']
result = subprocess.run(cmd, capture_output=True, text=True)
print(result.stdout)
# Out:
# C:/work/GitHub/dec-tree-py\Python\tests\m_classifier_test.py-1-from src.dec_tree.m_classifier import M_Classifier
# C:/work/GitHub/dec-tree-py\Python\tests\m_classifier_test.py-2-
# C:/work/GitHub/dec-tree-py\Python\tests\m_classifier_test.py:3:1:def test_m_classifier():
# C:/work/GitHub/dec-tree-py\Python\tests\m_classifier_test.py-4-    m_classifier = M_Classifier()
# C:/work/GitHub/dec-tree-py\Python\tests\m_classifier_test.py-5-    assert m_classifier() < 1.0
# --
# C:/work/GitHub/dec-tree-py\Python\src\child_channel.py-14-    STDOUT_END = 'out_end_###'
# C:/work/GitHub/dec-tree-py\Python\src\child_channel.py-15-
# C:/work/GitHub/dec-tree-py\Python\src\child_channel.py:16:5:    def __init__(self):
# C:/work/GitHub/dec-tree-py\Python\src\child_channel.py-17-        """
# C:/work/GitHub/dec-tree-py\Python\src\child_channel.py-18-        docstring
# --
# C:/work/GitHub/dec-tree-py\Python\src\child_channel.py-22-        self.json_object = None
# C:/work/GitHub/dec-tree-py\Python\src\child_channel.py-23-
# C:/work/GitHub/dec-tree-py\Python\src\child_channel.py:24:5:    def data_received(self, data: bytes):
# C:/work/GitHub/dec-tree-py\Python\src\child_channel.py-25-        """
# C:/work/GitHub/dec-tree-py\Python\src\child_channel.py-26-        docstring
# --
# C:/work/GitHub/dec-tree-py\Python\src\child_channel.py-47-
# C:/work/GitHub/dec-tree-py\Python\src\child_channel.py-48-
# C:/work/GitHub/dec-tree-py\Python\src\child_channel.py:49:5:    def get_json(self):
# C:/work/GitHub/dec-tree-py\Python\src\child_channel.py-50-        """
# C:/work/GitHub/dec-tree-py\Python\src\child_channel.py-51-        docstring
# --
# C:/work/GitHub/dec-tree-py\Python\src\child_channel.py-53-        self.json_object = json.loads(self.decoded_message)
# C:/work/GitHub/dec-tree-py\Python\src\child_channel.py-54-
# C:/work/GitHub/dec-tree-py\Python\src\child_channel.py:55:5:    def encode(self, jObj):
# C:/work/GitHub/dec-tree-py\Python\src\child_channel.py-56-        json_string = json.dumps(jObj)
# C:/work/GitHub/dec-tree-py\Python\src\child_channel.py-57-
# --
# C:/work/GitHub/dec-tree-py\Python\src\child_channel.py-60-        return encoded_string
# C:/work/GitHub/dec-tree-py\Python\src\child_channel.py-61-
# C:/work/GitHub/dec-tree-py\Python\src\child_channel.py:62:5:    def reply(self, jObj):
# C:/work/GitHub/dec-tree-py\Python\src\child_channel.py-63-        """
# C:/work/GitHub/dec-tree-py\Python\src\child_channel.py-64-        docstring
# --
# C:/work/GitHub/dec-tree-py\Python\src\child_message.py-15-    docstring
# C:/work/GitHub/dec-tree-py\Python\src\child_message.py-16-    """
# C:/work/GitHub/dec-tree-py\Python\src\child_message.py:17:5:    def __init__(self):
# C:/work/GitHub/dec-tree-py\Python\src\child_message.py-18-        """
# C:/work/GitHub/dec-tree-py\Python\src\child_message.py-19-        docstring
# --
# C:/work/GitHub/dec-tree-py\Python\src\child_message.py-23-        self.m_return_dict = {}
# C:/work/GitHub/dec-tree-py\Python\src\child_message.py-24-
# C:/work/GitHub/dec-tree-py\Python\src\child_message.py:25:5:    def m_return_reply(self):
# C:/work/GitHub/dec-tree-py\Python\src\child_message.py-26-        self.m_channel.reply(self.m_return_dict)
# C:/work/GitHub/dec-tree-py\Python\src\child_message.py-27-        self.json_object = None
# --
# C:/work/GitHub/dec-tree-py\Python\src\child_exec.py-18-    docstring
# C:/work/GitHub/dec-tree-py\Python\src\child_exec.py-19-    """
# C:/work/GitHub/dec-tree-py\Python\src\child_exec.py:20:5:    def __init__(self):
# C:/work/GitHub/dec-tree-py\Python\src\child_exec.py-21-        """
# C:/work/GitHub/dec-tree-py\Python\src\child_exec.py-22-        docstring
# --
# C:/work/GitHub/dec-tree-py\Python\src\child_exec.py-26-        self.iset = M_SettingsSingleton()
# C:/work/GitHub/dec-tree-py\Python\src\child_exec.py-27-
# C:/work/GitHub/dec-tree-py\Python\src\child_exec.py:28:5:    def __call__(self, *args: Any, **kwds: Any):
# C:/work/GitHub/dec-tree-py\Python\src\child_exec.py-29-        """
# C:/work/GitHub/dec-tree-py\Python\src\child_exec.py-30-        docstring
# --
# C:/work/GitHub/dec-tree-py\Python\src\child_exec.py-37-    docstring
# C:/work/GitHub/dec-tree-py\Python\src\child_exec.py-38-    """
# C:/work/GitHub/dec-tree-py\Python\src\child_exec.py:39:5:    def __init__(self):
# C:/work/GitHub/dec-tree-py\Python\src\child_exec.py-40-        """
# C:/work/GitHub/dec-tree-py\Python\src\child_exec.py-41-        docstring
# --
# C:/work/GitHub/dec-tree-py\Python\src\child_exec.py-43-        super().__init__()
# C:/work/GitHub/dec-tree-py\Python\src\child_exec.py-44-
# C:/work/GitHub/dec-tree-py\Python\src\child_exec.py:45:5:    def __call__(self, *args: Any, **kwds: Any):
# C:/work/GitHub/dec-tree-py\Python\src\child_exec.py-46-        """
# C:/work/GitHub/dec-tree-py\Python\src\child_exec.py-47-        docstring
# --
# C:/work/GitHub/dec-tree-py\Python\src\child_exec.py-84-        return self
# C:/work/GitHub/dec-tree-py\Python\src\child_exec.py-85-
# C:/work/GitHub/dec-tree-py\Python\src\child_exec.py:86:5:    def replace_args(self, x:str, decl):
# C:/work/GitHub/dec-tree-py\Python\src\child_exec.py-87-        """
# C:/work/GitHub/dec-tree-py\Python\src\child_exec.py-88-        docstring
# --
# C:/work/GitHub/dec-tree-py\Python\src\child_exec.py-99-        return result
# C:/work/GitHub/dec-tree-py\Python\src\child_exec.py-100-
# C:/work/GitHub/dec-tree-py\Python\src\child_exec.py:101:5:    def stringify(self, s, d):
# C:/work/GitHub/dec-tree-py\Python\src\child_exec.py-102-        """
# C:/work/GitHub/dec-tree-py\Python\src\child_exec.py-103-        docstring
# --
# C:/work/GitHub/dec-tree-py\Python\src\child_exec.py-118-    """
# C:/work/GitHub/dec-tree-py\Python\src\child_exec.py-119-    @staticmethod
# C:/work/GitHub/dec-tree-py\Python\src\child_exec.py:120:5:    def create_child_exec(message: ChildMessage):
# C:/work/GitHub/dec-tree-py\Python\src\child_exec.py-121-        """
# C:/work/GitHub/dec-tree-py\Python\src\child_exec.py-122-        docstring
# --
# C:/work/GitHub/dec-tree-py\Python\src\m_settings\m_settings.py-5-    _instance = None
# C:/work/GitHub/dec-tree-py\Python\src\m_settings\m_settings.py-6-
# C:/work/GitHub/dec-tree-py\Python\src\m_settings\m_settings.py:7:5:    def __new__(cls, *args, **kwargs):
# C:/work/GitHub/dec-tree-py\Python\src\m_settings\m_settings.py-8-        if cls._instance is None:
# C:/work/GitHub/dec-tree-py\Python\src\m_settings\m_settings.py-9-            cls._instance = super(M_SettingsSingleton, cls).__new__(cls, *args, **kwargs)
# C:/work/GitHub/dec-tree-py\Python\src\m_settings\m_settings.py-10-        return cls._instance
# C:/work/GitHub/dec-tree-py\Python\src\m_settings\m_settings.py-11-
# C:/work/GitHub/dec-tree-py\Python\src\m_settings\m_settings.py:12:5:    def __init__(self):
# C:/work/GitHub/dec-tree-py\Python\src\m_settings\m_settings.py-13-        """
# C:/work/GitHub/dec-tree-py\Python\src\m_settings\m_settings.py-14-        docstring
# --
# C:/work/GitHub/dec-tree-py\Python\src\m_settings\m_settings.py-23-            self.initialized = True
# C:/work/GitHub/dec-tree-py\Python\src\m_settings\m_settings.py-24-
# C:/work/GitHub/dec-tree-py\Python\src\m_settings\m_settings.py:25:5:    def addSettings(self, settings):
# C:/work/GitHub/dec-tree-py\Python\src\m_settings\m_settings.py-26-        """go through the settings dictionary and add them to the settings dictionary"""
# C:/work/GitHub/dec-tree-py\Python\src\m_settings\m_settings.py-27-        for key in settings:
# --
# C:/work/GitHub/dec-tree-py\Python\src\m_settings\m_settings.py-30-                self.addConf(settings[key])
# C:/work/GitHub/dec-tree-py\Python\src\m_settings\m_settings.py-31-
# C:/work/GitHub/dec-tree-py\Python\src\m_settings\m_settings.py:32:5:    def addConf(self, conf):
# C:/work/GitHub/dec-tree-py\Python\src\m_settings\m_settings.py-33-        """go through the configuration dictionary and add them to the configuration dictionary"""
# C:/work/GitHub/dec-tree-py\Python\src\m_settings\m_settings.py-34-        for key in conf:
# --
# C:/work/GitHub/dec-tree-py\Python\src\m_settings\m_settings.py-37-        self.addTry(self.m_conf[self.getCurrentTry()])
# C:/work/GitHub/dec-tree-py\Python\src\m_settings\m_settings.py-38-
# C:/work/GitHub/dec-tree-py\Python\src\m_settings\m_settings.py:39:5:    def addTry(self, try_dict):
# C:/work/GitHub/dec-tree-py\Python\src\m_settings\m_settings.py-40-        """go through the try dictionary and add them to the try dictionary"""
# C:/work/GitHub/dec-tree-py\Python\src\m_settings\m_settings.py-41-        for key in try_dict:
# C:/work/GitHub/dec-tree-py\Python\src\m_settings\m_settings.py-42-            self.m_try[key] = try_dict[key]
# C:/work/GitHub/dec-tree-py\Python\src\m_settings\m_settings.py-43-
# C:/work/GitHub/dec-tree-py\Python\src\m_settings\m_settings.py:44:5:    def getCurrentTry(self):
# C:/work/GitHub/dec-tree-py\Python\src\m_settings\m_settings.py-45-        """return the current try"""
# C:/work/GitHub/dec-tree-py\Python\src\m_settings\m_settings.py-46-        return self.m_conf['current_try']
# C:/work/GitHub/dec-tree-py\Python\src\m_settings\m_settings.py-47-
# C:/work/GitHub/dec-tree-py\Python\src\m_settings\m_settings.py:48:5:    def getTryFolder(self):
# C:/work/GitHub/dec-tree-py\Python\src\m_settings\m_settings.py-49-        """return the current try folder"""
# C:/work/GitHub/dec-tree-py\Python\src\m_settings\m_settings.py-50-        return self.m_set['rootFolder']+'/'+self.m_try['name']
# --
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop_analysis.py-8-class M_ShopAnalysis:
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop_analysis.py-9-
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop_analysis.py:10:5:    def __init__(self):
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop_analysis.py-11-        self.iset = M_SettingsSingleton()
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop_analysis.py-12-        #load the dataframe from pickle
# --
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop_analysis.py-14-
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop_analysis.py-15-    #method to plot yearly sell per item name
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop_analysis.py:16:5:    def plot_yearly_sell(self):
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop_analysis.py-17-        """
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop_analysis.py-18-        Plot the yearly sell per item name
# --
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop_analysis.py-34-
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop_analysis.py-35-    #method to plot yearly stock per item name
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop_analysis.py:36:5:    def plot_yearly_stock(self):
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop_analysis.py-37-        """
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop_analysis.py-38-        Plot the yearly stock per item name
# --
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_classifier.py-12-
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_classifier.py-13-class M_Classifier(object):
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_classifier.py:14:3:  def __init__(self) -> None:
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_classifier.py-15-    self.iset = M_SettingsSingleton()
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_classifier.py-16-    self.iris = load_iris()
# --
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_classifier.py-21-    self.iset.df['species'] = self.iris.target
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_classifier.py-22-
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_classifier.py:23:3:  def __call__(self, *args: Any, **kwds: Any) -> Any:
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_classifier.py-24-
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_classifier.py-25-    #iris_df
# --
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_classifier.py-53-    return accuracy
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_classifier.py-54-
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_classifier.py:55:3:  def plot_tree(self):
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_classifier.py-56-    """
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_classifier.py-57-    docstring
# --
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_classifier.py-62-    plt.savefig(self.iset.m_set['rootFolder']+'/decision_tree.png')
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_classifier.py-63-
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_classifier.py:64:3:  def plot_importance(self):
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_classifier.py-65-    """
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_classifier.py-66-    docstring
# --
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop.py-4-#class to manage the shop data
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop.py-5-class M_Shop:
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop.py:6:5:    def __init__(self):
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop.py-7-        self.shop = []
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop.py-8-        self.shop.append({"item":"Drill", "name":"Expensive drill"})
# --
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop.py-19-
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop.py-20-
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop.py:21:5:    def generate_ledger_df(self):
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop.py-22-        """
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop.py-23-        Generate a dataframe for shop items ledger from January 2019 to current month
# --
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop.py-54-        self.df = pd.DataFrame(ledger_entries)
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop.py-55-
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop.py:56:5:    def assign_impressions(self):
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop.py-57-        """
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop.py-58-        Assign impressions to the ledger randomly each month between 0 and 100
# --
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop.py-60-        self.df['impressions'] = np.random.randint(0, 100, size=len(self.df))
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop.py-61-
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop.py:62:5:    def assign_first_month_buy(self):
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop.py-63-        """
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop.py-64-        Assign a random number of buys to the first month for each item
# --
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop.py-67-            self.df.loc[(self.df['item'] == item['item']) & (self.df['name'] == item['name']) & (self.df['year'] == 2019) & (self.df['month'] == 1), 'buy'] = np.random.randint(10, 30)
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop.py-68-
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop.py:69:5:    def assign_demand(self):
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop.py-70-        """
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop.py-71-        Assign a random number of demands to each month for each item
# --
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop.py-76-                    self.df.loc[(self.df['item'] == item['item']) & (self.df['name'] == item['name']) & (self.df['year'] == year) & (self.df['month'] == month), 'demand'] = np.random.randint(0, 20)
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop.py-77-
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop.py:78:5:    def assign_first_month_sell(self):
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop.py-79-        """
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop.py-80-        Sell what is in demand in the first month
# --
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop.py-84-            self.df.loc[(self.df['item'] == item['item']) & (self.df['name'] == item['name']) & (self.df['year'] == 2019) & (self.df['month'] == 1), 'sell'] = min(self.df.loc[(self.df['item'] == item['item']) & (self.df['name'] == item['name']) & (self.df['year'] == 2019) & (self.df['month'] == 1), 'demand'].iloc[0], self.df.loc[(self.df['item'] == item['item']) & (self.df['name'] == item['name']) & (self.df['year'] == 2019) & (self.df['month'] == 1), 'buy'].iloc[0])
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop.py-85-
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop.py:86:5:    def update_stock(self, year, month):
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop.py-87-        """
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop.py-88-        Update the stock
# --
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop.py-99-                self.df.loc[(self.df['item'] == item['item']) & (self.df['name'] == item['name']) & (self.df['year'] == year) & (self.df['month'] == month), 'stock'] = int(self.df.loc[(self.df['item'] == item['item']) & (self.df['name'] == item['name']) & (self.df['year'] == year) & (self.df['month'] == month-1), 'stock'].iloc[0] + self.df.loc[(self.df['item'] == item['item']) & (self.df['name'] == item['name']) & (self.df['year'] == year) & (self.df['month'] == month), 'buy'].iloc[0] - self.df.loc[(self.df['item'] == item['item']) & (self.df['name'] == item['name']) & (self.df['year'] == year) & (self.df['month'] == month), 'sell'].iloc[0])
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop.py-100-
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop.py:101:5:    def buy_and_sell(self):
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop.py-102-        """
# C:/work/GitHub/dec-tree-py\Python\src\m_shop\m_shop.py-103-        Buy and sell items
# --
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_regressor.py-10-
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_regressor.py-11-class M_Regressor:
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_regressor.py:12:5:    def __init__(self):
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_regressor.py-13-        self.iset = M_SettingsSingleton()
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_regressor.py-14-        self.df = pd.read_pickle(self.iset.m_set['rootFolder'] + '/shop_data.pkl')
# --
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_regressor.py-17-        self.target = 'demand_next_sum'
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_regressor.py-18-
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_regressor.py:19:5:    def train_regressor(self):
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_regressor.py-20-        """
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_regressor.py-21-        Train a regressor using the shop data for item 'Cheap drill' sell prediction
# --
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_regressor.py-46-        self.iset.regressor.fit(X, y)
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_regressor.py-47-
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_regressor.py:48:5:    def plot_feature_importance(self):
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_regressor.py-49-        """
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_regressor.py-50-        Plot the feature importance
# --
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_regressor.py-65-        plt.savefig(self.iset.getTryFolder() + '/feature_importance.png')
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_regressor.py-66-
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_regressor.py:67:5:    def plot_sell_prediction(self):
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_regressor.py-68-        """
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_regressor.py-69-        Plot the sell prediction
# --
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_regressor.py-79-        plt.savefig(self.iset.getTryFolder() + '/sell_prediction.png')
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_regressor.py-80-
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_regressor.py:81:5:    def plot_seasonality(self):
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_regressor.py-82-        """
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_regressor.py-83-        Plot the seasonality
# --
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_regressor.py-93-        plt.savefig(self.iset.getTryFolder() + '/selltrend.png')
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_regressor.py-94-
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_regressor.py:95:5:    def calc_trends(self):
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_regressor.py-96-        """
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_regressor.py-97-        Calculate the trends
# --
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_dec_tree_clf.py-10-    _instance = None
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_dec_tree_clf.py-11-
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_dec_tree_clf.py:12:5:    def __new__(cls, *args, **kwargs):
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_dec_tree_clf.py-13-        if cls._instance is None:
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_dec_tree_clf.py-14-            cls._instance = super(M_DecTreeClfSingleton, cls).__new__(cls, *args, **kwargs)
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_dec_tree_clf.py-15-        return cls._instance
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_dec_tree_clf.py-16-
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_dec_tree_clf.py:17:5:    def __init__(self):
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_dec_tree_clf.py-18-        """
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_dec_tree_clf.py-19-        docstring
# --
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_dec_tree_clf.py-23-            self.initialized = True
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_dec_tree_clf.py-24-
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_dec_tree_clf.py:25:5:    def load_df(self):
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_dec_tree_clf.py-26-        """
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_dec_tree_clf.py-27-        Load a dataframe
# --
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_dec_tree_clf.py-30-        pass
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_dec_tree_clf.py-31-
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_dec_tree_clf.py:32:5:    def train_clf(self):
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_dec_tree_clf.py-33-        """
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_dec_tree_clf.py-34-        docstring
# --
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_dec_tree_clf.py-47-        return accuracy
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_dec_tree_clf.py-48-
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_dec_tree_clf.py:49:5:    def plot_tree(self):
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_dec_tree_clf.py-50-        """
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_dec_tree_clf.py-51-        Plot the decision tree with dynamic figsize
# --
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_dec_tree_clf.py-65-        plt.savefig(self.iset.getTryFolder()+'/decision_tree.png')
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_dec_tree_clf.py-66-
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_dec_tree_clf.py:67:5:    def plot_feature_importance(self):
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_dec_tree_clf.py-68-        """
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_dec_tree_clf.py-69-        docstring
# --
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_dec_tree_iris.py-4-
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_dec_tree_iris.py-5-class M_DecTreeIris(M_DecTreeClfSingleton):
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_dec_tree_iris.py:6:5:    def __init__(self):
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_dec_tree_iris.py-7-        """
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_dec_tree_iris.py-8-        docstring
# --
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_dec_tree_iris.py-13-            self.initialized = True
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_dec_tree_iris.py-14-
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_dec_tree_iris.py:15:5:    def load_df(self):
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_dec_tree_iris.py-16-        """
# C:/work/GitHub/dec-tree-py\Python\src\dec_tree\m_dec_tree_iris.py-17-        Load a dataframe
