# %% [markdown]
# # Ripgrep Contextual Search Example
# This notebook demonstrates how to use ripgrep to search for patterns in files, including lines before and after each match, and store the results in a pandas DataFrame for contextual analysis.

# %%
# Import required libraries
import subprocess
import pandas as pd

# %% [markdown]
# ## Define ripgrep search function with context
# This function runs ripgrep with options to include lines before and after each match, and parses the output into a DataFrame.

# %%
import json
import os
from pathlib import Path
import datetime
def ripgrep_search_with_context(pattern, path='.', before=2, after=2, extra_args=None):
    cmd = ['rg', '--json', f'-B{before}', f'-A{after}', pattern, path]
    if extra_args:
        cmd.extend(extra_args)
    result = subprocess.run(cmd, capture_output=True, text=True)
    lines = result.stdout.strip().split('\n')
    search_path = Path(path).resolve()
    grouped = {}
    for line in lines:
        if not line.strip():
            continue
        try:
            obj = json.loads(line)
        except Exception:
            continue
        if obj.get('type') == 'begin':
            current_file = Path(obj['data']['path']['text']).resolve()
            current_group = []
        elif obj.get('type') in ['match', 'context']:
            current_group.append(obj)
        elif obj.get('type') == 'end':
            # Process group for this file
            # Find all match objects and their context
            for i, item in enumerate(current_group):
                if item.get('type') == 'match':
                    # Gather context before and after
                    context_lines = []
                    # before context
                    for j in range(i-before, i):
                        if 0 <= j < len(current_group) and current_group[j].get('type') == 'context':
                            context_lines.append(current_group[j]['data']['lines']['text'])
                    # matched line
                    match_text = item['data']['lines']['text']
                    context_lines.append(match_text)
                    # after context
                    for j in range(i+1, i+1+after):
                        if 0 <= j < len(current_group) and current_group[j].get('type') == 'context':
                            context_lines.append(current_group[j]['data']['lines']['text'])
                    file_path = Path(item['data']['path']['text']).resolve()
                    try:
                        stat = file_path.stat()
                        created = getattr(stat, 'st_birthtime', stat.st_ctime)
                        created = datetime.datetime.fromtimestamp(created)
                        modified = datetime.datetime.fromtimestamp(stat.st_mtime)
                    except Exception:
                        created = None
                        modified = None
                    try:
                        folder = str(file_path.parent.relative_to(search_path))
                    except ValueError:
                        folder = str(file_path.parent)
                    file_info = {
                        'file': str(file_path),
                        'search_path': str(search_path),
                        'folder': folder,
                        'file_name': file_path.name,
                        'file_ext': file_path.suffix,
                        'created': created,
                        'modified': modified
                    }
                    for submatch in item['data']['submatches']:
                        row = {
                            'line': item['data']['line_number'],
                            'col': submatch['start'],
                            'text': match_text,
                            'context': '\n'.join(context_lines),
                            'type': 'match'
                        }
                        row.update(file_info)
                        grouped.setdefault(str(file_path), []).append(row)
    # Flatten all match rows
    data = [row for rows in grouped.values() for row in rows]
    return pd.DataFrame(data)

# %% [markdown]
# ## Run a contextual search
# Search for the word 'def' in Python files, including 2 lines before and after each match, and display results.

# %%
df = ripgrep_search_with_context('def', path='C:/work/GitHub/dec-tree-py', before=2, after=2, extra_args=['--type', 'py'])
#df.info()
df
# Out:
#      line  col                                               text     type  \
# 0       1  NaN  from src.dec_tree.m_classifier import M_Classi...  context
# 1       2  NaN                                               \r\n  context
# 2       3  0.0                       def test_m_classifier():\r\n    match
# 3       4  NaN                  m_classifier = M_Classifier()\r\n  context
# 4       5  NaN                        assert m_classifier() < 1.0  context
# ..    ...  ...                                                ...      ...
# 249    93  NaN          plt.savefig(self.iset.getTryFolder() +...  context
# 250    94  NaN                                               \r\n  context
# 251    95  4.0                         def calc_trends(self):\r\n    match
# 252    96  NaN                                            """\r\n  context
# 253    97  NaN                           Calculate the trends\r\n  context
#
#                                                   file  \
# 0    C:\work\GitHub\dec-tree-py\Python\tests\m_clas...
# 1    C:\work\GitHub\dec-tree-py\Python\tests\m_clas...
# 2    C:\work\GitHub\dec-tree-py\Python\tests\m_clas...
# 3    C:\work\GitHub\dec-tree-py\Python\tests\m_clas...
# 4    C:\work\GitHub\dec-tree-py\Python\tests\m_clas...
# ..                                                 ...
# 249  C:\work\GitHub\dec-tree-py\Python\src\dec_tree...
# 250  C:\work\GitHub\dec-tree-py\Python\src\dec_tree...
# 251  C:\work\GitHub\dec-tree-py\Python\src\dec_tree...
# 252  C:\work\GitHub\dec-tree-py\Python\src\dec_tree...
# 253  C:\work\GitHub\dec-tree-py\Python\src\dec_tree...
#
#                     search_path               folder             file_name  \
# 0    C:\work\GitHub\dec-tree-py         Python\tests  m_classifier_test.py
# 1    C:\work\GitHub\dec-tree-py         Python\tests  m_classifier_test.py
# 2    C:\work\GitHub\dec-tree-py         Python\tests  m_classifier_test.py
# 3    C:\work\GitHub\dec-tree-py         Python\tests  m_classifier_test.py
# 4    C:\work\GitHub\dec-tree-py         Python\tests  m_classifier_test.py
# ..                          ...                  ...                   ...
# 249  C:\work\GitHub\dec-tree-py  Python\src\dec_tree        m_regressor.py
# 250  C:\work\GitHub\dec-tree-py  Python\src\dec_tree        m_regressor.py
# 251  C:\work\GitHub\dec-tree-py  Python\src\dec_tree        m_regressor.py
# 252  C:\work\GitHub\dec-tree-py  Python\src\dec_tree        m_regressor.py
# 253  C:\work\GitHub\dec-tree-py  Python\src\dec_tree        m_regressor.py
#
#     file_ext                    created                   modified
# 0        .py 2024-08-16 13:24:38.139333 2024-08-16 13:37:56.382003
# 1        .py 2024-08-16 13:24:38.139333 2024-08-16 13:37:56.382003
# 2        .py 2024-08-16 13:24:38.139333 2024-08-16 13:37:56.382003
# 3        .py 2024-08-16 13:24:38.139333 2024-08-16 13:37:56.382003
# 4        .py 2024-08-16 13:24:38.139333 2024-08-16 13:37:56.382003
# ..       ...                        ...                        ...
# 249      .py 2024-09-04 10:15:11.721226 2024-09-23 01:16:27.159902
# 250      .py 2024-09-04 10:15:11.721226 2024-09-23 01:16:27.159902
# 251      .py 2024-09-04 10:15:11.721226 2024-09-23 01:16:27.159902
# 252      .py 2024-09-04 10:15:11.721226 2024-09-23 01:16:27.159902
# 253      .py 2024-09-04 10:15:11.721226 2024-09-23 01:16:27.159902
#
# [254 rows x 11 columns]

# %%
# Debug: Print raw ripgrep output to help diagnose parsing issues
cmd = ['rg', '--vimgrep', '-B2', '-A2', 'def', 'C:/work/GitHub/dec-tree-py', '--type', 'py', '--json']
result = subprocess.run(cmd, capture_output=True, text=True)
print(result.stdout)
# Out:
# {"type":"begin","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\tests\\m_classifier_test.py"}}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\tests\\m_classifier_test.py"},"lines":{"text":"from src.dec_tree.m_classifier import M_Classifier\r\n"},"line_number":1,"absolute_offset":0,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\tests\\m_classifier_test.py"},"lines":{"text":"\r\n"},"line_number":2,"absolute_offset":52,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\tests\\m_classifier_test.py"},"lines":{"text":"def test_m_classifier():\r\n"},"line_number":3,"absolute_offset":54,"submatches":[{"match":{"text":"def"},"start":0,"end":3}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\tests\\m_classifier_test.py"},"lines":{"text":"    m_classifier = M_Classifier()\r\n"},"line_number":4,"absolute_offset":80,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\tests\\m_classifier_test.py"},"lines":{"text":"    assert m_classifier() < 1.0"},"line_number":5,"absolute_offset":115,"submatches":[]}}
# {"type":"end","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\tests\\m_classifier_test.py"},"binary_offset":null,"stats":{"elapsed":{"secs":0,"nanos":209300,"human":"0.000209s"},"searches":1,"searches_with_match":1,"bytes_searched":146,"bytes_printed":1217,"matched_lines":1,"matches":1}}}
# {"type":"begin","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_channel.py"}}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_channel.py"},"lines":{"text":"    STDOUT_END = 'out_end_###'\r\n"},"line_number":14,"absolute_offset":257,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_channel.py"},"lines":{"text":"\r\n"},"line_number":15,"absolute_offset":289,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_channel.py"},"lines":{"text":"    def __init__(self):\r\n"},"line_number":16,"absolute_offset":291,"submatches":[{"match":{"text":"def"},"start":4,"end":7}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_channel.py"},"lines":{"text":"        \"\"\"\r\n"},"line_number":17,"absolute_offset":316,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_channel.py"},"lines":{"text":"        docstring\r\n"},"line_number":18,"absolute_offset":329,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_channel.py"},"lines":{"text":"        self.json_object = None\r\n"},"line_number":22,"absolute_offset":441,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_channel.py"},"lines":{"text":"\r\n"},"line_number":23,"absolute_offset":474,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_channel.py"},"lines":{"text":"    def data_received(self, data: bytes):\r\n"},"line_number":24,"absolute_offset":476,"submatches":[{"match":{"text":"def"},"start":4,"end":7}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_channel.py"},"lines":{"text":"        \"\"\"\r\n"},"line_number":25,"absolute_offset":519,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_channel.py"},"lines":{"text":"        docstring\r\n"},"line_number":26,"absolute_offset":532,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_channel.py"},"lines":{"text":"\r\n"},"line_number":47,"absolute_offset":1358,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_channel.py"},"lines":{"text":"\r\n"},"line_number":48,"absolute_offset":1360,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_channel.py"},"lines":{"text":"    def get_json(self):\r\n"},"line_number":49,"absolute_offset":1362,"submatches":[{"match":{"text":"def"},"start":4,"end":7}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_channel.py"},"lines":{"text":"        \"\"\"\r\n"},"line_number":50,"absolute_offset":1387,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_channel.py"},"lines":{"text":"        docstring\r\n"},"line_number":51,"absolute_offset":1400,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_channel.py"},"lines":{"text":"        self.json_object = json.loads(self.decoded_message)\r\n"},"line_number":53,"absolute_offset":1432,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_channel.py"},"lines":{"text":"\r\n"},"line_number":54,"absolute_offset":1493,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_channel.py"},"lines":{"text":"    def encode(self, jObj):\r\n"},"line_number":55,"absolute_offset":1495,"submatches":[{"match":{"text":"def"},"start":4,"end":7}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_channel.py"},"lines":{"text":"        json_string = json.dumps(jObj)\r\n"},"line_number":56,"absolute_offset":1524,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_channel.py"},"lines":{"text":"\r\n"},"line_number":57,"absolute_offset":1564,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_channel.py"},"lines":{"text":"        return encoded_string\r\n"},"line_number":60,"absolute_offset":1713,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_channel.py"},"lines":{"text":"    \r\n"},"line_number":61,"absolute_offset":1744,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_channel.py"},"lines":{"text":"    def reply(self, jObj):\r\n"},"line_number":62,"absolute_offset":1750,"submatches":[{"match":{"text":"def"},"start":4,"end":7}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_channel.py"},"lines":{"text":"        \"\"\"\r\n"},"line_number":63,"absolute_offset":1778,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_channel.py"},"lines":{"text":"        docstring\r\n"},"line_number":64,"absolute_offset":1791,"submatches":[]}}
# {"type":"end","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_channel.py"},"binary_offset":null,"stats":{"elapsed":{"secs":0,"nanos":126200,"human":"0.000126s"},"searches":1,"searches_with_match":1,"bytes_searched":1952,"bytes_printed":5347,"matched_lines":5,"matches":5}}}
# {"type":"begin","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_exec.py"}}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_exec.py"},"lines":{"text":"    docstring\r\n"},"line_number":18,"absolute_offset":348,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_exec.py"},"lines":{"text":"    \"\"\"\r\n"},"line_number":19,"absolute_offset":363,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_exec.py"},"lines":{"text":"    def __init__(self):\r\n"},"line_number":20,"absolute_offset":372,"submatches":[{"match":{"text":"def"},"start":4,"end":7}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_exec.py"},"lines":{"text":"        \"\"\"\r\n"},"line_number":21,"absolute_offset":397,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_exec.py"},"lines":{"text":"        docstring\r\n"},"line_number":22,"absolute_offset":410,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_exec.py"},"lines":{"text":"        self.iset = M_SettingsSingleton()\r\n"},"line_number":26,"absolute_offset":518,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_exec.py"},"lines":{"text":"\r\n"},"line_number":27,"absolute_offset":561,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_exec.py"},"lines":{"text":"    def __call__(self, *args: Any, **kwds: Any):\r\n"},"line_number":28,"absolute_offset":563,"submatches":[{"match":{"text":"def"},"start":4,"end":7}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_exec.py"},"lines":{"text":"        \"\"\"\r\n"},"line_number":29,"absolute_offset":613,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_exec.py"},"lines":{"text":"        docstring\r\n"},"line_number":30,"absolute_offset":626,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_exec.py"},"lines":{"text":"    docstring\r\n"},"line_number":37,"absolute_offset":754,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_exec.py"},"lines":{"text":"    \"\"\"\r\n"},"line_number":38,"absolute_offset":769,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_exec.py"},"lines":{"text":"    def __init__(self):\r\n"},"line_number":39,"absolute_offset":778,"submatches":[{"match":{"text":"def"},"start":4,"end":7}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_exec.py"},"lines":{"text":"        \"\"\"\r\n"},"line_number":40,"absolute_offset":803,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_exec.py"},"lines":{"text":"        docstring\r\n"},"line_number":41,"absolute_offset":816,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_exec.py"},"lines":{"text":"        super().__init__()\r\n"},"line_number":43,"absolute_offset":848,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_exec.py"},"lines":{"text":"\r\n"},"line_number":44,"absolute_offset":876,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_exec.py"},"lines":{"text":"    def __call__(self, *args: Any, **kwds: Any):\r\n"},"line_number":45,"absolute_offset":878,"submatches":[{"match":{"text":"def"},"start":4,"end":7}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_exec.py"},"lines":{"text":"        \"\"\"\r\n"},"line_number":46,"absolute_offset":928,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_exec.py"},"lines":{"text":"        docstring\r\n"},"line_number":47,"absolute_offset":941,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_exec.py"},"lines":{"text":"        return self\r\n"},"line_number":84,"absolute_offset":2558,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_exec.py"},"lines":{"text":"    \r\n"},"line_number":85,"absolute_offset":2579,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_exec.py"},"lines":{"text":"    def replace_args(self, x:str, decl):\r\n"},"line_number":86,"absolute_offset":2585,"submatches":[{"match":{"text":"def"},"start":4,"end":7}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_exec.py"},"lines":{"text":"        \"\"\"\r\n"},"line_number":87,"absolute_offset":2627,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_exec.py"},"lines":{"text":"        docstring\r\n"},"line_number":88,"absolute_offset":2640,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_exec.py"},"lines":{"text":"        return result\r\n"},"line_number":99,"absolute_offset":3032,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_exec.py"},"lines":{"text":"    \r\n"},"line_number":100,"absolute_offset":3055,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_exec.py"},"lines":{"text":"    def stringify(self, s, d):\r\n"},"line_number":101,"absolute_offset":3061,"submatches":[{"match":{"text":"def"},"start":4,"end":7}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_exec.py"},"lines":{"text":"        \"\"\"\r\n"},"line_number":102,"absolute_offset":3093,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_exec.py"},"lines":{"text":"        docstring\r\n"},"line_number":103,"absolute_offset":3106,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_exec.py"},"lines":{"text":"    \"\"\"\r\n"},"line_number":118,"absolute_offset":3406,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_exec.py"},"lines":{"text":"    @staticmethod\r\n"},"line_number":119,"absolute_offset":3415,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_exec.py"},"lines":{"text":"    def create_child_exec(message: ChildMessage):\r\n"},"line_number":120,"absolute_offset":3434,"submatches":[{"match":{"text":"def"},"start":4,"end":7}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_exec.py"},"lines":{"text":"        \"\"\"\r\n"},"line_number":121,"absolute_offset":3485,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_exec.py"},"lines":{"text":"        docstring\r\n"},"line_number":122,"absolute_offset":3498,"submatches":[]}}
# {"type":"end","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_exec.py"},"binary_offset":null,"stats":{"elapsed":{"secs":0,"nanos":204000,"human":"0.000204s"},"searches":1,"searches_with_match":1,"bytes_searched":3970,"bytes_printed":7369,"matched_lines":7,"matches":7}}}
# {"type":"begin","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_message.py"}}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_message.py"},"lines":{"text":"    docstring\r\n"},"line_number":15,"absolute_offset":219,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_message.py"},"lines":{"text":"    \"\"\"\r\n"},"line_number":16,"absolute_offset":234,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_message.py"},"lines":{"text":"    def __init__(self):\r\n"},"line_number":17,"absolute_offset":243,"submatches":[{"match":{"text":"def"},"start":4,"end":7}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_message.py"},"lines":{"text":"        \"\"\"\r\n"},"line_number":18,"absolute_offset":268,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_message.py"},"lines":{"text":"        docstring\r\n"},"line_number":19,"absolute_offset":281,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_message.py"},"lines":{"text":"        self.m_return_dict = {}\r\n"},"line_number":23,"absolute_offset":387,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_message.py"},"lines":{"text":"\r\n"},"line_number":24,"absolute_offset":420,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_message.py"},"lines":{"text":"    def m_return_reply(self):\r\n"},"line_number":25,"absolute_offset":422,"submatches":[{"match":{"text":"def"},"start":4,"end":7}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_message.py"},"lines":{"text":"        self.m_channel.reply(self.m_return_dict)\r\n"},"line_number":26,"absolute_offset":453,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_message.py"},"lines":{"text":"        self.json_object = None\r\n"},"line_number":27,"absolute_offset":503,"submatches":[]}}
# {"type":"end","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\child_message.py"},"binary_offset":null,"stats":{"elapsed":{"secs":0,"nanos":137200,"human":"0.000137s"},"searches":1,"searches_with_match":1,"bytes_searched":569,"bytes_printed":2228,"matched_lines":2,"matches":2}}}
# {"type":"begin","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop.py"}}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop.py"},"lines":{"text":"#class to manage the shop data\r\n"},"line_number":4,"absolute_offset":43,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop.py"},"lines":{"text":"class M_Shop:\r\n"},"line_number":5,"absolute_offset":75,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop.py"},"lines":{"text":"    def __init__(self):\r\n"},"line_number":6,"absolute_offset":90,"submatches":[{"match":{"text":"def"},"start":4,"end":7}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop.py"},"lines":{"text":"        self.shop = []\r\n"},"line_number":7,"absolute_offset":115,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop.py"},"lines":{"text":"        self.shop.append({\"item\":\"Drill\", \"name\":\"Expensive drill\"})\r\n"},"line_number":8,"absolute_offset":139,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop.py"},"lines":{"text":"\r\n"},"line_number":19,"absolute_offset":766,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop.py"},"lines":{"text":"\r\n"},"line_number":20,"absolute_offset":768,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop.py"},"lines":{"text":"    def generate_ledger_df(self):\r\n"},"line_number":21,"absolute_offset":770,"submatches":[{"match":{"text":"def"},"start":4,"end":7}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop.py"},"lines":{"text":"        \"\"\"\r\n"},"line_number":22,"absolute_offset":805,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop.py"},"lines":{"text":"        Generate a dataframe for shop items ledger from January 2019 to current month\r\n"},"line_number":23,"absolute_offset":818,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop.py"},"lines":{"text":"        self.df = pd.DataFrame(ledger_entries)\r\n"},"line_number":54,"absolute_offset":1830,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop.py"},"lines":{"text":"\r\n"},"line_number":55,"absolute_offset":1878,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop.py"},"lines":{"text":"    def assign_impressions(self):\r\n"},"line_number":56,"absolute_offset":1880,"submatches":[{"match":{"text":"def"},"start":4,"end":7}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop.py"},"lines":{"text":"        \"\"\"\r\n"},"line_number":57,"absolute_offset":1915,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop.py"},"lines":{"text":"        Assign impressions to the ledger randomly each month between 0 and 100\r\n"},"line_number":58,"absolute_offset":1928,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop.py"},"lines":{"text":"        self.df['impressions'] = np.random.randint(0, 100, size=len(self.df))\r\n"},"line_number":60,"absolute_offset":2021,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop.py"},"lines":{"text":"\r\n"},"line_number":61,"absolute_offset":2100,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop.py"},"lines":{"text":"    def assign_first_month_buy(self):\r\n"},"line_number":62,"absolute_offset":2102,"submatches":[{"match":{"text":"def"},"start":4,"end":7}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop.py"},"lines":{"text":"        \"\"\"\r\n"},"line_number":63,"absolute_offset":2141,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop.py"},"lines":{"text":"        Assign a random number of buys to the first month for each item\r\n"},"line_number":64,"absolute_offset":2154,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop.py"},"lines":{"text":"            self.df.loc[(self.df['item'] == item['item']) & (self.df['name'] == item['name']) & (self.df['year'] == 2019) & (self.df['month'] == 1), 'buy'] = np.random.randint(10, 30)\r\n"},"line_number":67,"absolute_offset":2272,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop.py"},"lines":{"text":"\r\n"},"line_number":68,"absolute_offset":2457,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop.py"},"lines":{"text":"    def assign_demand(self):\r\n"},"line_number":69,"absolute_offset":2459,"submatches":[{"match":{"text":"def"},"start":4,"end":7}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop.py"},"lines":{"text":"        \"\"\"\r\n"},"line_number":70,"absolute_offset":2489,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop.py"},"lines":{"text":"        Assign a random number of demands to each month for each item\r\n"},"line_number":71,"absolute_offset":2502,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop.py"},"lines":{"text":"                    self.df.loc[(self.df['item'] == item['item']) & (self.df['name'] == item['name']) & (self.df['year'] == year) & (self.df['month'] == month), 'demand'] = np.random.randint(0, 20)    \r\n"},"line_number":76,"absolute_offset":2706,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop.py"},"lines":{"text":"\r\n"},"line_number":77,"absolute_offset":2909,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop.py"},"lines":{"text":"    def assign_first_month_sell(self):\r\n"},"line_number":78,"absolute_offset":2911,"submatches":[{"match":{"text":"def"},"start":4,"end":7}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop.py"},"lines":{"text":"        \"\"\"\r\n"},"line_number":79,"absolute_offset":2951,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop.py"},"lines":{"text":"        Sell what is in demand in the first month\r\n"},"line_number":80,"absolute_offset":2964,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop.py"},"lines":{"text":"            self.df.loc[(self.df['item'] == item['item']) & (self.df['name'] == item['name']) & (self.df['year'] == 2019) & (self.df['month'] == 1), 'sell'] = min(self.df.loc[(self.df['item'] == item['item']) & (self.df['name'] == item['name']) & (self.df['year'] == 2019) & (self.df['month'] == 1), 'demand'].iloc[0], self.df.loc[(self.df['item'] == item['item']) & (self.df['name'] == item['name']) & (self.df['year'] == 2019) & (self.df['month'] == 1), 'buy'].iloc[0])\r\n"},"line_number":84,"absolute_offset":3129,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop.py"},"lines":{"text":"\r\n"},"line_number":85,"absolute_offset":3602,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop.py"},"lines":{"text":"    def update_stock(self, year, month):\r\n"},"line_number":86,"absolute_offset":3604,"submatches":[{"match":{"text":"def"},"start":4,"end":7}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop.py"},"lines":{"text":"        \"\"\"\r\n"},"line_number":87,"absolute_offset":3646,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop.py"},"lines":{"text":"        Update the stock\r\n"},"line_number":88,"absolute_offset":3659,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop.py"},"lines":{"text":"                self.df.loc[(self.df['item'] == item['item']) & (self.df['name'] == item['name']) & (self.df['year'] == year) & (self.df['month'] == month), 'stock'] = int(self.df.loc[(self.df['item'] == item['item']) & (self.df['name'] == item['name']) & (self.df['year'] == year) & (self.df['month'] == month-1), 'stock'].iloc[0] + self.df.loc[(self.df['item'] == item['item']) & (self.df['name'] == item['name']) & (self.df['year'] == year) & (self.df['month'] == month), 'buy'].iloc[0] - self.df.loc[(self.df['item'] == item['item']) & (self.df['name'] == item['name']) & (self.df['year'] == year) & (self.df['month'] == month), 'sell'].iloc[0])\r\n"},"line_number":99,"absolute_offset":5044,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop.py"},"lines":{"text":"\r\n"},"line_number":100,"absolute_offset":5695,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop.py"},"lines":{"text":"    def buy_and_sell(self):\r\n"},"line_number":101,"absolute_offset":5697,"submatches":[{"match":{"text":"def"},"start":4,"end":7}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop.py"},"lines":{"text":"        \"\"\"\r\n"},"line_number":102,"absolute_offset":5726,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop.py"},"lines":{"text":"        Buy and sell items\r\n"},"line_number":103,"absolute_offset":5739,"submatches":[]}}
# {"type":"end","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop.py"},"binary_offset":null,"stats":{"elapsed":{"secs":0,"nanos":137400,"human":"0.000137s"},"searches":1,"searches_with_match":1,"bytes_searched":8912,"bytes_printed":10336,"matched_lines":8,"matches":8}}}
# {"type":"begin","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_settings\\m_settings.py"}}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_settings\\m_settings.py"},"lines":{"text":"    _instance = None\r\n"},"line_number":5,"absolute_offset":123,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_settings\\m_settings.py"},"lines":{"text":"\r\n"},"line_number":6,"absolute_offset":145,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_settings\\m_settings.py"},"lines":{"text":"    def __new__(cls, *args, **kwargs):\r\n"},"line_number":7,"absolute_offset":147,"submatches":[{"match":{"text":"def"},"start":4,"end":7}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_settings\\m_settings.py"},"lines":{"text":"        if cls._instance is None:\r\n"},"line_number":8,"absolute_offset":187,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_settings\\m_settings.py"},"lines":{"text":"            cls._instance = super(M_SettingsSingleton, cls).__new__(cls, *args, **kwargs)\r\n"},"line_number":9,"absolute_offset":222,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_settings\\m_settings.py"},"lines":{"text":"        return cls._instance\r\n"},"line_number":10,"absolute_offset":313,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_settings\\m_settings.py"},"lines":{"text":"\r\n"},"line_number":11,"absolute_offset":343,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_settings\\m_settings.py"},"lines":{"text":"    def __init__(self):\r\n"},"line_number":12,"absolute_offset":345,"submatches":[{"match":{"text":"def"},"start":4,"end":7}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_settings\\m_settings.py"},"lines":{"text":"        \"\"\"\r\n"},"line_number":13,"absolute_offset":370,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_settings\\m_settings.py"},"lines":{"text":"        docstring\r\n"},"line_number":14,"absolute_offset":383,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_settings\\m_settings.py"},"lines":{"text":"            self.initialized = True\r\n"},"line_number":23,"absolute_offset":729,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_settings\\m_settings.py"},"lines":{"text":"\r\n"},"line_number":24,"absolute_offset":766,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_settings\\m_settings.py"},"lines":{"text":"    def addSettings(self, settings):\r\n"},"line_number":25,"absolute_offset":768,"submatches":[{"match":{"text":"def"},"start":4,"end":7}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_settings\\m_settings.py"},"lines":{"text":"        \"\"\"go through the settings dictionary and add them to the settings dictionary\"\"\"\r\n"},"line_number":26,"absolute_offset":806,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_settings\\m_settings.py"},"lines":{"text":"        for key in settings:\r\n"},"line_number":27,"absolute_offset":896,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_settings\\m_settings.py"},"lines":{"text":"                self.addConf(settings[key])\r\n"},"line_number":30,"absolute_offset":1009,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_settings\\m_settings.py"},"lines":{"text":"\r\n"},"line_number":31,"absolute_offset":1054,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_settings\\m_settings.py"},"lines":{"text":"    def addConf(self, conf):\r\n"},"line_number":32,"absolute_offset":1056,"submatches":[{"match":{"text":"def"},"start":4,"end":7}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_settings\\m_settings.py"},"lines":{"text":"        \"\"\"go through the configuration dictionary and add them to the configuration dictionary\"\"\"\r\n"},"line_number":33,"absolute_offset":1086,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_settings\\m_settings.py"},"lines":{"text":"        for key in conf:\r\n"},"line_number":34,"absolute_offset":1186,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_settings\\m_settings.py"},"lines":{"text":"        self.addTry(self.m_conf[self.getCurrentTry()])\r\n"},"line_number":37,"absolute_offset":1256,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_settings\\m_settings.py"},"lines":{"text":"\r\n"},"line_number":38,"absolute_offset":1312,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_settings\\m_settings.py"},"lines":{"text":"    def addTry(self, try_dict):\r\n"},"line_number":39,"absolute_offset":1314,"submatches":[{"match":{"text":"def"},"start":4,"end":7}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_settings\\m_settings.py"},"lines":{"text":"        \"\"\"go through the try dictionary and add them to the try dictionary\"\"\"\r\n"},"line_number":40,"absolute_offset":1347,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_settings\\m_settings.py"},"lines":{"text":"        for key in try_dict:\r\n"},"line_number":41,"absolute_offset":1427,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_settings\\m_settings.py"},"lines":{"text":"            self.m_try[key] = try_dict[key]\r\n"},"line_number":42,"absolute_offset":1457,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_settings\\m_settings.py"},"lines":{"text":"\r\n"},"line_number":43,"absolute_offset":1502,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_settings\\m_settings.py"},"lines":{"text":"    def getCurrentTry(self):\r\n"},"line_number":44,"absolute_offset":1504,"submatches":[{"match":{"text":"def"},"start":4,"end":7}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_settings\\m_settings.py"},"lines":{"text":"        \"\"\"return the current try\"\"\"\r\n"},"line_number":45,"absolute_offset":1534,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_settings\\m_settings.py"},"lines":{"text":"        return self.m_conf['current_try']\r\n"},"line_number":46,"absolute_offset":1572,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_settings\\m_settings.py"},"lines":{"text":"    \r\n"},"line_number":47,"absolute_offset":1615,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_settings\\m_settings.py"},"lines":{"text":"    def getTryFolder(self):\r\n"},"line_number":48,"absolute_offset":1621,"submatches":[{"match":{"text":"def"},"start":4,"end":7}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_settings\\m_settings.py"},"lines":{"text":"        \"\"\"return the current try folder\"\"\"\r\n"},"line_number":49,"absolute_offset":1650,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_settings\\m_settings.py"},"lines":{"text":"        return self.m_set['rootFolder']+'/'+self.m_try['name']\r\n"},"line_number":50,"absolute_offset":1695,"submatches":[]}}
# {"type":"end","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_settings\\m_settings.py"},"binary_offset":null,"stats":{"elapsed":{"secs":0,"nanos":96700,"human":"0.000097s"},"searches":1,"searches_with_match":1,"bytes_searched":1765,"bytes_printed":8080,"matched_lines":7,"matches":7}}}
# {"type":"begin","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_classifier.py"}}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_classifier.py"},"lines":{"text":"\r\n"},"line_number":12,"absolute_offset":362,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_classifier.py"},"lines":{"text":"class M_Classifier(object):\r\n"},"line_number":13,"absolute_offset":364,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_classifier.py"},"lines":{"text":"  def __init__(self) -> None:\r\n"},"line_number":14,"absolute_offset":393,"submatches":[{"match":{"text":"def"},"start":2,"end":5}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_classifier.py"},"lines":{"text":"    self.iset = M_SettingsSingleton()\r\n"},"line_number":15,"absolute_offset":424,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_classifier.py"},"lines":{"text":"    self.iris = load_iris()\r\n"},"line_number":16,"absolute_offset":463,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_classifier.py"},"lines":{"text":"    self.iset.df['species'] = self.iris.target\r\n"},"line_number":21,"absolute_offset":606,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_classifier.py"},"lines":{"text":"\r\n"},"line_number":22,"absolute_offset":654,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_classifier.py"},"lines":{"text":"  def __call__(self, *args: Any, **kwds: Any) -> Any:\r\n"},"line_number":23,"absolute_offset":656,"submatches":[{"match":{"text":"def"},"start":2,"end":5}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_classifier.py"},"lines":{"text":"\r\n"},"line_number":24,"absolute_offset":711,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_classifier.py"},"lines":{"text":"    #iris_df\r\n"},"line_number":25,"absolute_offset":713,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_classifier.py"},"lines":{"text":"    return accuracy\r\n"},"line_number":53,"absolute_offset":1530,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_classifier.py"},"lines":{"text":"  \r\n"},"line_number":54,"absolute_offset":1551,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_classifier.py"},"lines":{"text":"  def plot_tree(self):\r\n"},"line_number":55,"absolute_offset":1555,"submatches":[{"match":{"text":"def"},"start":2,"end":5}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_classifier.py"},"lines":{"text":"    \"\"\"\r\n"},"line_number":56,"absolute_offset":1579,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_classifier.py"},"lines":{"text":"    docstring\r\n"},"line_number":57,"absolute_offset":1588,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_classifier.py"},"lines":{"text":"    plt.savefig(self.iset.m_set['rootFolder']+'/decision_tree.png')\r\n"},"line_number":62,"absolute_offset":1793,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_classifier.py"},"lines":{"text":"\r\n"},"line_number":63,"absolute_offset":1862,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_classifier.py"},"lines":{"text":"  def plot_importance(self):\r\n"},"line_number":64,"absolute_offset":1864,"submatches":[{"match":{"text":"def"},"start":2,"end":5}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_classifier.py"},"lines":{"text":"    \"\"\"\r\n"},"line_number":65,"absolute_offset":1894,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_classifier.py"},"lines":{"text":"    docstring\r\n"},"line_number":66,"absolute_offset":1903,"submatches":[]}}
# {"type":"end","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_classifier.py"},"binary_offset":null,"stats":{"elapsed":{"secs":0,"nanos":103000,"human":"0.000103s"},"searches":1,"searches_with_match":1,"bytes_searched":2379,"bytes_printed":4536,"matched_lines":4,"matches":4}}}
# {"type":"begin","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_dec_tree_clf.py"}}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_dec_tree_clf.py"},"lines":{"text":"    _instance = None\r\n"},"line_number":10,"absolute_offset":274,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_dec_tree_clf.py"},"lines":{"text":"\r\n"},"line_number":11,"absolute_offset":296,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_dec_tree_clf.py"},"lines":{"text":"    def __new__(cls, *args, **kwargs):\r\n"},"line_number":12,"absolute_offset":298,"submatches":[{"match":{"text":"def"},"start":4,"end":7}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_dec_tree_clf.py"},"lines":{"text":"        if cls._instance is None:\r\n"},"line_number":13,"absolute_offset":338,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_dec_tree_clf.py"},"lines":{"text":"            cls._instance = super(M_DecTreeClfSingleton, cls).__new__(cls, *args, **kwargs)\r\n"},"line_number":14,"absolute_offset":373,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_dec_tree_clf.py"},"lines":{"text":"        return cls._instance\r\n"},"line_number":15,"absolute_offset":466,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_dec_tree_clf.py"},"lines":{"text":"\r\n"},"line_number":16,"absolute_offset":496,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_dec_tree_clf.py"},"lines":{"text":"    def __init__(self):\r\n"},"line_number":17,"absolute_offset":498,"submatches":[{"match":{"text":"def"},"start":4,"end":7}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_dec_tree_clf.py"},"lines":{"text":"        \"\"\"\r\n"},"line_number":18,"absolute_offset":523,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_dec_tree_clf.py"},"lines":{"text":"        docstring\r\n"},"line_number":19,"absolute_offset":536,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_dec_tree_clf.py"},"lines":{"text":"            self.initialized = True\r\n"},"line_number":23,"absolute_offset":700,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_dec_tree_clf.py"},"lines":{"text":"\r\n"},"line_number":24,"absolute_offset":737,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_dec_tree_clf.py"},"lines":{"text":"    def load_df(self):\r\n"},"line_number":25,"absolute_offset":739,"submatches":[{"match":{"text":"def"},"start":4,"end":7}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_dec_tree_clf.py"},"lines":{"text":"        \"\"\"\r\n"},"line_number":26,"absolute_offset":763,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_dec_tree_clf.py"},"lines":{"text":"        Load a dataframe \r\n"},"line_number":27,"absolute_offset":776,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_dec_tree_clf.py"},"lines":{"text":"        pass\r\n"},"line_number":30,"absolute_offset":847,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_dec_tree_clf.py"},"lines":{"text":"\r\n"},"line_number":31,"absolute_offset":861,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_dec_tree_clf.py"},"lines":{"text":"    def train_clf(self):\r\n"},"line_number":32,"absolute_offset":863,"submatches":[{"match":{"text":"def"},"start":4,"end":7}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_dec_tree_clf.py"},"lines":{"text":"        \"\"\"\r\n"},"line_number":33,"absolute_offset":889,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_dec_tree_clf.py"},"lines":{"text":"        docstring\r\n"},"line_number":34,"absolute_offset":902,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_dec_tree_clf.py"},"lines":{"text":"        return accuracy\r\n"},"line_number":47,"absolute_offset":1333,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_dec_tree_clf.py"},"lines":{"text":"    \r\n"},"line_number":48,"absolute_offset":1358,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_dec_tree_clf.py"},"lines":{"text":"    def plot_tree(self):\r\n"},"line_number":49,"absolute_offset":1364,"submatches":[{"match":{"text":"def"},"start":4,"end":7}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_dec_tree_clf.py"},"lines":{"text":"        \"\"\"\r\n"},"line_number":50,"absolute_offset":1390,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_dec_tree_clf.py"},"lines":{"text":"        Plot the decision tree with dynamic figsize\r\n"},"line_number":51,"absolute_offset":1403,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_dec_tree_clf.py"},"lines":{"text":"        plt.savefig(self.iset.getTryFolder()+'/decision_tree.png')\r\n"},"line_number":65,"absolute_offset":2043,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_dec_tree_clf.py"},"lines":{"text":"\r\n"},"line_number":66,"absolute_offset":2111,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_dec_tree_clf.py"},"lines":{"text":"    def plot_feature_importance(self):\r\n"},"line_number":67,"absolute_offset":2113,"submatches":[{"match":{"text":"def"},"start":4,"end":7}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_dec_tree_clf.py"},"lines":{"text":"        \"\"\"\r\n"},"line_number":68,"absolute_offset":2153,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_dec_tree_clf.py"},"lines":{"text":"        docstring\r\n"},"line_number":69,"absolute_offset":2166,"submatches":[]}}
# {"type":"end","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_dec_tree_clf.py"},"binary_offset":null,"stats":{"elapsed":{"secs":0,"nanos":105500,"human":"0.000106s"},"searches":1,"searches_with_match":1,"bytes_searched":2697,"bytes_printed":6861,"matched_lines":6,"matches":6}}}
# {"type":"begin","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_dec_tree_iris.py"}}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_dec_tree_iris.py"},"lines":{"text":"\r\n"},"line_number":4,"absolute_offset":120,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_dec_tree_iris.py"},"lines":{"text":"class M_DecTreeIris(M_DecTreeClfSingleton):\r\n"},"line_number":5,"absolute_offset":122,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_dec_tree_iris.py"},"lines":{"text":"    def __init__(self):\r\n"},"line_number":6,"absolute_offset":167,"submatches":[{"match":{"text":"def"},"start":4,"end":7}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_dec_tree_iris.py"},"lines":{"text":"        \"\"\"\r\n"},"line_number":7,"absolute_offset":192,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_dec_tree_iris.py"},"lines":{"text":"        docstring\r\n"},"line_number":8,"absolute_offset":205,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_dec_tree_iris.py"},"lines":{"text":"            self.initialized = True\r\n"},"line_number":13,"absolute_offset":391,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_dec_tree_iris.py"},"lines":{"text":"\r\n"},"line_number":14,"absolute_offset":428,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_dec_tree_iris.py"},"lines":{"text":"    def load_df(self):\r\n"},"line_number":15,"absolute_offset":430,"submatches":[{"match":{"text":"def"},"start":4,"end":7}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_dec_tree_iris.py"},"lines":{"text":"        \"\"\"\r\n"},"line_number":16,"absolute_offset":454,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_dec_tree_iris.py"},"lines":{"text":"        Load a dataframe \r\n"},"line_number":17,"absolute_offset":467,"submatches":[]}}
# {"type":"end","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_dec_tree_iris.py"},"binary_offset":null,"stats":{"elapsed":{"secs":0,"nanos":81000,"human":"0.000081s"},"searches":1,"searches_with_match":1,"bytes_searched":708,"bytes_printed":2332,"matched_lines":2,"matches":2}}}
# {"type":"begin","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_regressor.py"}}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_regressor.py"},"lines":{"text":"\r\n"},"line_number":10,"absolute_offset":346,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_regressor.py"},"lines":{"text":"class M_Regressor:\r\n"},"line_number":11,"absolute_offset":348,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_regressor.py"},"lines":{"text":"    def __init__(self):\r\n"},"line_number":12,"absolute_offset":368,"submatches":[{"match":{"text":"def"},"start":4,"end":7}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_regressor.py"},"lines":{"text":"        self.iset = M_SettingsSingleton()\r\n"},"line_number":13,"absolute_offset":393,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_regressor.py"},"lines":{"text":"        self.df = pd.read_pickle(self.iset.m_set['rootFolder'] + '/shop_data.pkl')\r\n"},"line_number":14,"absolute_offset":436,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_regressor.py"},"lines":{"text":"        self.target = 'demand_next_sum'\r\n"},"line_number":17,"absolute_offset":628,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_regressor.py"},"lines":{"text":"\r\n"},"line_number":18,"absolute_offset":669,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_regressor.py"},"lines":{"text":"    def train_regressor(self):\r\n"},"line_number":19,"absolute_offset":671,"submatches":[{"match":{"text":"def"},"start":4,"end":7}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_regressor.py"},"lines":{"text":"        \"\"\"\r\n"},"line_number":20,"absolute_offset":703,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_regressor.py"},"lines":{"text":"        Train a regressor using the shop data for item 'Cheap drill' sell prediction\r\n"},"line_number":21,"absolute_offset":716,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_regressor.py"},"lines":{"text":"        self.iset.regressor.fit(X, y)\r\n"},"line_number":46,"absolute_offset":1745,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_regressor.py"},"lines":{"text":"\r\n"},"line_number":47,"absolute_offset":1784,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_regressor.py"},"lines":{"text":"    def plot_feature_importance(self):\r\n"},"line_number":48,"absolute_offset":1786,"submatches":[{"match":{"text":"def"},"start":4,"end":7}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_regressor.py"},"lines":{"text":"        \"\"\"\r\n"},"line_number":49,"absolute_offset":1826,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_regressor.py"},"lines":{"text":"        Plot the feature importance\r\n"},"line_number":50,"absolute_offset":1839,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_regressor.py"},"lines":{"text":"        plt.savefig(self.iset.getTryFolder() + '/feature_importance.png')\r\n"},"line_number":65,"absolute_offset":2510,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_regressor.py"},"lines":{"text":"\r\n"},"line_number":66,"absolute_offset":2585,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_regressor.py"},"lines":{"text":"    def plot_sell_prediction(self):\r\n"},"line_number":67,"absolute_offset":2587,"submatches":[{"match":{"text":"def"},"start":4,"end":7}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_regressor.py"},"lines":{"text":"        \"\"\"\r\n"},"line_number":68,"absolute_offset":2624,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_regressor.py"},"lines":{"text":"        Plot the sell prediction\r\n"},"line_number":69,"absolute_offset":2637,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_regressor.py"},"lines":{"text":"        plt.savefig(self.iset.getTryFolder() + '/sell_prediction.png')\r\n"},"line_number":79,"absolute_offset":3094,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_regressor.py"},"lines":{"text":"\r\n"},"line_number":80,"absolute_offset":3166,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_regressor.py"},"lines":{"text":"    def plot_seasonality(self):\r\n"},"line_number":81,"absolute_offset":3168,"submatches":[{"match":{"text":"def"},"start":4,"end":7}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_regressor.py"},"lines":{"text":"        \"\"\"\r\n"},"line_number":82,"absolute_offset":3201,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_regressor.py"},"lines":{"text":"        Plot the seasonality\r\n"},"line_number":83,"absolute_offset":3214,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_regressor.py"},"lines":{"text":"        plt.savefig(self.iset.getTryFolder() + '/selltrend.png')\r\n"},"line_number":93,"absolute_offset":3619,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_regressor.py"},"lines":{"text":"\r\n"},"line_number":94,"absolute_offset":3685,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_regressor.py"},"lines":{"text":"    def calc_trends(self):\r\n"},"line_number":95,"absolute_offset":3687,"submatches":[{"match":{"text":"def"},"start":4,"end":7}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_regressor.py"},"lines":{"text":"        \"\"\"\r\n"},"line_number":96,"absolute_offset":3715,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_regressor.py"},"lines":{"text":"        Calculate the trends\r\n"},"line_number":97,"absolute_offset":3728,"submatches":[]}}
# {"type":"end","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\dec_tree\\m_regressor.py"},"binary_offset":null,"stats":{"elapsed":{"secs":0,"nanos":153500,"human":"0.000153s"},"searches":1,"searches_with_match":1,"bytes_searched":4351,"bytes_printed":6984,"matched_lines":6,"matches":6}}}
# {"type":"begin","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop_analysis.py"}}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop_analysis.py"},"lines":{"text":"class M_ShopAnalysis:\r\n"},"line_number":8,"absolute_offset":200,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop_analysis.py"},"lines":{"text":"\r\n"},"line_number":9,"absolute_offset":223,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop_analysis.py"},"lines":{"text":"    def __init__(self):\r\n"},"line_number":10,"absolute_offset":225,"submatches":[{"match":{"text":"def"},"start":4,"end":7}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop_analysis.py"},"lines":{"text":"        self.iset = M_SettingsSingleton()\r\n"},"line_number":11,"absolute_offset":250,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop_analysis.py"},"lines":{"text":"        #load the dataframe from pickle\r\n"},"line_number":12,"absolute_offset":293,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop_analysis.py"},"lines":{"text":"\r\n"},"line_number":14,"absolute_offset":417,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop_analysis.py"},"lines":{"text":"    #method to plot yearly sell per item name\r\n"},"line_number":15,"absolute_offset":419,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop_analysis.py"},"lines":{"text":"    def plot_yearly_sell(self):\r\n"},"line_number":16,"absolute_offset":466,"submatches":[{"match":{"text":"def"},"start":4,"end":7}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop_analysis.py"},"lines":{"text":"        \"\"\"\r\n"},"line_number":17,"absolute_offset":499,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop_analysis.py"},"lines":{"text":"        Plot the yearly sell per item name\r\n"},"line_number":18,"absolute_offset":512,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop_analysis.py"},"lines":{"text":"\r\n"},"line_number":34,"absolute_offset":1136,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop_analysis.py"},"lines":{"text":"    #method to plot yearly stock per item name\r\n"},"line_number":35,"absolute_offset":1138,"submatches":[]}}
# {"type":"match","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop_analysis.py"},"lines":{"text":"    def plot_yearly_stock(self):\r\n"},"line_number":36,"absolute_offset":1186,"submatches":[{"match":{"text":"def"},"start":4,"end":7}]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop_analysis.py"},"lines":{"text":"        \"\"\"\r\n"},"line_number":37,"absolute_offset":1220,"submatches":[]}}
# {"type":"context","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop_analysis.py"},"lines":{"text":"        Plot the yearly stock per item name\r\n"},"line_number":38,"absolute_offset":1233,"submatches":[]}}
# {"type":"end","data":{"path":{"text":"C:/work/GitHub/dec-tree-py\\Python\\src\\m_shop\\m_shop_analysis.py"},"binary_offset":null,"stats":{"elapsed":{"secs":0,"nanos":109100,"human":"0.000109s"},"searches":1,"searches_with_match":1,"bytes_searched":1701,"bytes_printed":3521,"matched_lines":3,"matches":3}}}
# {"data":{"elapsed_total":{"human":"0.112191s","nanos":112190900,"secs":0},"stats":{"bytes_printed":58811,"bytes_searched":29150,"elapsed":{"human":"0.001463s","nanos":1462900,"secs":0},"matched_lines":51,"matches":51,"searches":11,"searches_with_match":11}},"type":"summary"}
